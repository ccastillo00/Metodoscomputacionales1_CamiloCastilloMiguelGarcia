# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1000
R = 1
u = np.random.rand()

phi = np.random.uniform(0, 2*np.pi, N)
theta = np.random.uniform(0, np.pi, N)
r = R*u**(1/3)
x = np.sin(theta) * np.cos(phi)
y = np.sin(theta) * np.sin(phi)
z = np.cos(theta)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, marker='.', color='blue')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
ax.set_zlim([-1,1])


plt.show()

# %%
Ixx = (sum(y**2+z**2))/N
Iyy = (sum(x**2+z**2))/N
Izz = (sum(x**2+y**2))/N
Ixy = (sum(-x*y))/N

# %%
print(Ixx)
print(Iyy)
print(Izz)
print(Ixy)
print(I)
# Out:
# 0.749738354247775
# 0.7465694467360746
# 0.5036921990161499
# -0.003927233813647746

# %% [markdown]
# La densidad de la esfera es uniforme porque la densidad es igualmente uniforme. Así que la rotación sea por donde sea va a rotar de la misma manera. Asimismo, el producto de inercia entre los 3 puntos va a ser igual por la uniformidad de la esfera y de su densidad que es igual a 0
